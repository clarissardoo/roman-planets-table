# %% [markdown]
# # Detection probabilities and integration times
#
# Computes detection probabilities, flux contrasts, and integration times for CPP targets.
#
# **Band/mode assignment:**
# - **eps Eri b**: WFOV modes only — bands 1, 4 (`IMG_WFB1_SPC`, `IMG_WFB4_SPC`)
# - **All other planets**: NFOV modes — bands 1, 3, 4 (`IMG_NFB1_HLC`, `SPEC_NFB3_SPC`, `IMG_WFB4_SPC`)
#
# RV only and RV+HGCA posteriors are processed in separate cells.

# %% [markdown]
# ### Imports

# %%
# Autoreload extension
# %load_ext autoreload
# %autoreload 2
from astroquery.vizier import Vizier
Vizier.SERVER = 'vizier.cfa.harvard.edu'

# %%
import os, numpy as np, pandas as pd
from astropy.time import Time
from astropy.table import Table
from decimal import Decimal
from astropy import units as u, constants as c
import matplotlib.pyplot as plt
from roman_pointing.roman_pointing import calcRomanAngles, getL2Positions
from astroquery.simbad import Simbad
from astropy.coordinates import (
    SkyCoord,
    Distance,
    BarycentricMeanEcliptic,
)
from roman_table import *

# %% [markdown]
# ### Helper Functions

# %%
def get_GB_sunang(ts):
    # ts must be astropy.Time object
    simbad = Simbad()
    simbad.add_votable_fields("pmra", "pmdec", "plx_value", "rvz_radvel")
    res = simbad.query_object("Sagittarius A*")
    gb = SkyCoord(
        res["ra"].value.data[0],
        res["dec"].value.data[0],
        unit=(res["ra"].unit, res["dec"].unit),
        frame="icrs",
        distance=Distance(8 * u.kpc),
        pm_ra_cosdec=0 * res["pmra"].unit,
        pm_dec=0 * res["pmdec"].unit,
        radial_velocity=0 * res["rvz_radvel"].unit,
        equinox="J2000",
        obstime="J2000",
    ).transform_to(BarycentricMeanEcliptic)
    sun_ang_ref, _, _, _ = calcRomanAngles(
        gb, ts, getL2Positions(ts)
    )
    return sun_ang_ref

def get_targ_sunang(star, ts):
    # ts must be astropy.Time object
    simbad_name = " ".join(star.split("_"))
    simbad = Simbad()
    simbad.add_votable_fields("pmra", "pmdec", "plx_value", "rvz_radvel")
    res = simbad.query_object(simbad_name)
    target = SkyCoord(
        res["ra"].value.data[0],
        res["dec"].value.data[0],
        unit=(res["ra"].unit, res["dec"].unit),
        frame="icrs",
        distance=Distance(parallax=res["plx_value"].value.data[0] * res["plx_value"].unit),
        pm_ra_cosdec=res["pmra"].value.data[0] * res["pmra"].unit,
        pm_dec=res["pmdec"].value.data[0] * res["pmdec"].unit,
        radial_velocity=res["rvz_radvel"].value.data[0] * res["rvz_radvel"].unit,
        equinox="J2000",
        obstime="J2000",
    ).transform_to(BarycentricMeanEcliptic)

    sun_ang_targ, _, _, _ = calcRomanAngles(
        target, ts, getL2Positions(ts)
    )
    return sun_ang_targ

# %% [markdown]
# ### Contrast Curves and Albedos

# %%
# NFOV contrast curve (used for all NFOV bands and WFOV band 4)
concurve_fpath = 'concurves/concurve_optimistic.csv'
concurve_df = pd.read_csv(concurve_fpath)
concurve_df['D'] = 2.4
concurve_df['sep_mas'] = concurve_df.loD * concurve_df['lambda'] * 1e-9 / concurve_df['D'] * u.radian.to(u.mas)
display(concurve_df)
concurve_nfov = np.array([
    concurve_df.sep_mas.values,
    concurve_df.contr.values,
])

# WFOV Band 1 contrast curve (used for eps Eri b Band 1)
cgperf_fpath = '/opt/homebrew/anaconda3/envs/roman_orbits/lib/python3.12/site-packages/cgi_noise/data/Photometry/CGPERF_SPC_WFB1_260206.csv'
concurve_wfb1_df = pd.read_csv(cgperf_fpath, comment='#')
concurve_wfb1_df['sep_mas'] = concurve_wfb1_df['r_lam_D'].astype(float) * 575e-9 / 2.363 * u.radian.to(u.mas)
concurve_wfov_b1 = np.array([
    concurve_wfb1_df.sep_mas.values,
    concurve_wfb1_df.contrast.values,
])
print(f"WFOV Band 1 separation range: {concurve_wfov_b1[0][0]:.1f} - {concurve_wfov_b1[0][-1]:.1f} mas")

# Albedos (placeholder until Dmitry provides updated values)
# Band wls from: https://roman.ipac.caltech.edu/docs/Coronagraph_Technical_Information.updated.pdf
# Albedos from: https://ui.adsabs.harvard.edu/abs/1998Icar..133..134K/abstract
albedo_dict = {
    1: 0.4,
    3: 0.4,
    4: 0.35,
}
albedo_std = 0.1
# Out:
#     loD         contr  lambda  t_int_hr  fpp  SNR    D     sep_mas
# 0   3.0  1.000000e-01     575        10    2    5  2.4  148.252829
# 1   3.1  4.400000e-09     575        10    2    5  2.4  153.194590
# 2   3.5  4.400000e-09     575        10    2    5  2.4  172.961634
# 3   4.0  3.100000e-09     575        10    2    5  2.4  197.670439
# 4   4.5  3.100000e-09     575        10    2    5  2.4  222.379244
# 5   5.0  3.100000e-09     575        10    2    5  2.4  247.088049
# 6   5.5  2.200000e-09     575        10    2    5  2.4  271.796854
# 7   6.1  2.200000e-09     575        10    2    5  2.4  301.447420
# 8   7.0  2.200000e-09     575        10    2    5  2.4  345.923269
# 9   8.0  2.200000e-09     575        10    2    5  2.4  395.340879
# 10  8.5  2.200000e-09     575        10    2    5  2.4  420.049684
# 11  8.8  2.200000e-09     575        10    2    5  2.4  434.874967
# 12  9.0  1.000000e-01     575        10    2    5  2.4  444.758488
# ...

# %% [markdown]
# ### Band / Mode Configuration

# %%
# EXOSIMS imports for integration time calculation
import json
import EXOSIMS.Prototypes.TargetList
import EXOSIMS.Prototypes.TimeKeeping
import EXOSIMS.Observatory.ObservatoryL2Halo
import copy
from corgietc.corgietc import corgietc
from pathlib import Path

# Per-planet band and observing mode configuration
# eps Eri b: WFOV (bands 1, 4)
# All others: NFOV (bands 1, 3, 4)

WFOV_PLANETS = {'eps_Eri_b'}

def get_planet_config(planet):
    """Return (bands, obs_mode_dict, contrast_curve_dict) for a planet."""
    if planet in WFOV_PLANETS:
        bands = [1, 4]
        obs_modes = {
            1: 'IMG_WFB1_SPC',
            4: 'IMG_WFB4_SPC',
        }
        contrast_curves = {
            1: concurve_wfov_b1,
            4: concurve_nfov,  # TODO: load dedicated WFOV band 4 contrast curve if available
        }
        show_wfov = True
    else:
        bands = [1, 3, 4]
        obs_modes = {
            1: 'IMG_NFB1_HLC',
            3: 'SPEC_NFB3_SPC',
            4: 'IMG_WFB4_SPC',
        }
        contrast_curves = {
            1: concurve_nfov,
            3: concurve_nfov,
            4: concurve_nfov,
        }
        show_wfov = False
    return bands, obs_modes, contrast_curves, show_wfov

# Collect the union of all bands used (for summary dict columns)
ALL_BANDS = [1, 3, 4]

semesters = [
    ("2026-12-01", "2027-06-30"),
    ("2027-07-01", "2027-12-31"),
    ("2028-01-01", "2028-06-30"),
]

print("Configuration loaded.")
for planet in list(orbit_params.keys())[:3]:
    bands, modes, _, wfov = get_planet_config(planet)
    print(f"  {planet}: bands={bands}, WFOV={wfov}")
print(f"  eps_Eri_b: bands={get_planet_config('eps_Eri_b')[0]}, WFOV={get_planet_config('eps_Eri_b')[3]}")
# Out:
# Configuration loaded.
#   eps_Eri_b: bands=[1, 4], WFOV=True
#   ups_And_d: bands=[1, 3, 4], WFOV=False
#   14_Her_b: bands=[1, 3, 4], WFOV=False
#   eps_Eri_b: bands=[1, 4], WFOV=True

# %% [markdown]
# ### Shared Processing Logic

# %%
def init_summary_dict():
    """Initialize empty summary dictionary with columns for all bands."""
    summary_dict = {'planet': []}
    for sem in range(1, len(semesters) + 1):
        for band in ALL_BANDS:
            summary_dict[f'peak_pdet_sem{sem}_band{band}'] = []
            summary_dict[f'peak_date_sem{sem}_band{band}'] = []
            summary_dict[f'mean_pdet_sem{sem}_band{band}'] = []
            summary_dict[f'sep_range_sem{sem}_band{band}'] = []
            summary_dict[f'fc_range_sem{sem}_band{band}'] = []
            summary_dict[f'mag_range_sem{sem}_band{band}'] = []
            summary_dict[f'inttime_opt_range_sem{sem}_band{band}'] = []
            summary_dict[f'inttime_con_range_sem{sem}_band{band}'] = []
    return summary_dict


def fill_missing_bands(summary_dict, planet_bands):
    """Pad summary_dict with None for bands this planet doesn't use."""
    for sem in range(1, len(semesters) + 1):
        for band in ALL_BANDS:
            if band not in planet_bands:
                for key_prefix in ['peak_pdet', 'peak_date', 'mean_pdet',
                                   'sep_range', 'fc_range', 'mag_range',
                                   'inttime_opt_range', 'inttime_con_range']:
                    summary_dict[f'{key_prefix}_sem{sem}_band{band}'].append(None)


def process_planet_band(planet, band, point_cloud, obs_mode, concurve,
                        summary_dict, orbit_props_dir, fname_out,
                        show_wfov=False, start_date=None, end_date=None):
    """Process a single planet+band: flux contrast, detectability, int times, obs windows, summary."""

    # Flux contrast
    print(f'  Calculating flux contrast & detectability (band {band})...')
    albedos = np.random.normal(albedo_dict[band], albedo_std,
                               size=point_cloud['sep_mas'].shape)
    phase_angle_rad = point_cloud['phase_angle_deg'] * np.pi / 180.
    point_cloud['lambert_phase'] = (np.sin(phase_angle_rad) +
                                    (np.pi - phase_angle_rad) *
                                    np.cos(phase_angle_rad)) / np.pi
    point_cloud['phi_x_a'] = point_cloud['lambert_phase'] * albedos
    point_cloud['flux_contrast'] = (point_cloud['phi_x_a'] *
                                    (point_cloud['r_pl_rjup'] *
                                     u.R_jup.to(u.AU) /
                                     point_cloud['orbital_radius_au'])**2)

    # Detectability
    point_cloud['is_detectable'] = is_detectable(
        point_cloud['sep_mas'], point_cloud['flux_contrast'], concurve)
    point_cloud['detection_probability'] = weighted_mean(
        point_cloud['is_detectable'], weights=point_cloud['ln_likelihood'])

    # Integration times
    print(f'  Calculating integration times (band {band})...')
    point_cloud = calc_integration_time_for_cloud(
        planet, point_cloud,
        target_snr=5,
        obs_mode=obs_mode,
        band=band,
        params=orbit_params[planet],
        min_det_prob=0.01,
        n_inttime_samples=2000,
    )

    # Observation windows
    print(f'  Getting observation windows...')
    times = Time(point_cloud['epoch_mjd'][:, 0], format='mjd')
    sun_ang_ref = get_GB_sunang(times)
    point_cloud['GB_not_observable'] = ~((sun_ang_ref.to_value(u.deg) > 54) &
                                         (sun_ang_ref.to_value(u.deg) < 126))
    star = orbit_params[planet]['star']
    sun_ang_targ = get_targ_sunang(star, times)
    point_cloud['targ_observable'] = ((sun_ang_targ.to_value(u.deg) > 54) &
                                      (sun_ang_targ.to_value(u.deg) < 126))

    # Summary CSV
    print(f'  Writing summary CSV...')
    csv_data = gen_summary_csv(
        planet, point_cloud, orbit_props_dir, fname_out + '_withDetProb')

    # Semester statistics
    for s, semester in enumerate(semesters):
        snum = s + 1
        s_start, s_end = Time(list(semester))
        dates_iso = Time(list(csv_data.date_iso.values))
        sem_df = csv_data.loc[(dates_iso > s_start) & (dates_iso < s_end)]

        peak_pdet = str('%.2f' % (np.max(sem_df.det_probability))).lstrip('-')
        peak_date = sem_df.date_iso.iloc[np.argmax(sem_df.det_probability)][:10]
        mean_pdet = str('%.2f' % (np.mean(sem_df.det_probability))).lstrip('-')
        sep_range = (f'{np.round(np.min(sem_df.separation_mas_16th), 0)} - '
                     f'{np.round(np.max(sem_df.separation_mas_84th), 0)}')
        fc_range = ('%.2E' % Decimal(np.min(sem_df.flux_contrast_16th)) + ' - ' +
                    '%.2E' % Decimal(np.max(sem_df.flux_contrast_84th)))

        if 'integration_time_hours_opt_median' in sem_df.columns:
            inttime_opt_range = (
                f'{np.round(np.nanmin(sem_df.integration_time_hours_opt_16th), 1)} - '
                f'{np.round(np.nanmax(sem_df.integration_time_hours_opt_84th), 1)}')
            inttime_con_range = (
                f'{np.round(np.nanmin(sem_df.integration_time_hours_con_16th), 1)} - '
                f'{np.round(np.nanmax(sem_df.integration_time_hours_con_84th), 1)}')
        else:
            inttime_opt_range = None
            inttime_con_range = None

        print(f'    Sem {snum}: peak pdet={peak_pdet} on {peak_date}')

        summary_dict[f'peak_pdet_sem{snum}_band{band}'].append(peak_pdet)
        summary_dict[f'peak_date_sem{snum}_band{band}'].append(peak_date)
        summary_dict[f'mean_pdet_sem{snum}_band{band}'].append(mean_pdet)
        summary_dict[f'sep_range_sem{snum}_band{band}'].append(sep_range)
        summary_dict[f'fc_range_sem{snum}_band{band}'].append(fc_range)
        summary_dict[f'mag_range_sem{snum}_band{band}'].append(None)
        summary_dict[f'inttime_opt_range_sem{snum}_band{band}'].append(inttime_opt_range)
        summary_dict[f'inttime_con_range_sem{snum}_band{band}'].append(inttime_con_range)

    # Plot
    print(f'  Plotting...')
    plot_outfpath = os.path.join(orbit_props_dir, fname_out)
    plot_orbital_parameters(
        planet, csv_data, plot_outfpath,
        override_lan=0.,
        start_date=start_date, end_date=end_date,
        figsize=None, fig_ext='png',
        show_plots=True,
        band=band, show_WFOV=show_wfov)

    return csv_data

# %% [markdown]
# ### RadVel Posteriors — Detection Probabilities + Integration Times

# %%
# RadVel detection probabilities with integration times
testing = False

radvel_planets = [p for p, v in orbit_params.items()
                  if v.get('posterior_type', 'radvel') == 'radvel']
start_date, end_date = "2026-12-01", "2028-06-30"
orbit_props_dir = '/Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_radvel/'

summary_dict_rv = init_summary_dict()

for p, planet in enumerate(radvel_planets):
    bands, obs_modes, contrast_curves, show_wfov = get_planet_config(planet)
    summary_dict_rv['planet'].append(planet)

    print(f'\n{"="*60}')
    print(f'Planet {p+1}/{len(radvel_planets)}: {planet}')
    print(f'  Bands: {bands}, WFOV: {show_wfov}')
    print(f'{"="*60}')

    for band in bands:
        fname_in = f"{planet}_{start_date}_to_{end_date}_RVOnly"
        fname_out = fname_in + f'_Band{band}'

        # Load point cloud
        point_cloud_fname = f"{fname_in}_PointCloud.pkl"
        point_cloud = load_point_cloud(planet, i_dir=orbit_props_dir,
                                       fname=point_cloud_fname)

        csv_data = process_planet_band(
            planet, band, point_cloud,
            obs_mode=obs_modes[band],
            concurve=contrast_curves[band],
            summary_dict=summary_dict_rv,
            orbit_props_dir=orbit_props_dir,
            fname_out=fname_out,
            show_wfov=show_wfov,
            start_date=start_date, end_date=end_date,
        )

        if testing:
            break

    # Fill None for bands this planet doesn't use
    fill_missing_bands(summary_dict_rv, bands)

    if testing:
        break

# Save summary
print('\nSaving RadVel summary table...')
summary_df_rv = pd.DataFrame(summary_dict_rv)
summary_fpath = os.path.join(orbit_props_dir,
                             f'detection_summary_{start_date}_to_{end_date}.csv')
summary_df_rv.to_csv(summary_fpath, index=False)
print(f'Summary saved to {summary_fpath}')
# Out:
# ...
# Planet 1/2: eps_Eri_b
#   Bands: [1, 4], WFOV: True
# ...
# Loading point cloud from /Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_radvel/eps_Eri_b_2026-12-01_to_2028-06-30_RVOnly_PointCloud.pkl
#   Calculating flux contrast & detectability (band 1)...
#   Calculating integration times (band 1)...
# Imported HIPfromSimbad (implementation) from EXOSIMS.StarCatalog.HIPfromSimbad
# Imported corgietc (named file) from /opt/homebrew/a[...]ages/corgietc/corgietc.py
# Imported Stark (implementation) from EXOSIMS.ZodiacalLight.Stark
# Imported PostProcessing (prototype) from EXOSIMS.Prototypes.PostProcessing
# Imported GalaxiesFaintStars (implementation) from EXOSIMS.BackgroundSources.GalaxiesFaintStars
# Imported Completeness (prototype) from EXOSIMS.Prototypes.Completeness
# Imported PlanetPopulation (prototype) from EXOSIMS.Prototypes.PlanetPopulation
# Imported ForecasterMod (implementation) from EXOSIMS.PlanetPhysicalModel.ForecasterMod
# ...

# %% [markdown]
# ### Orbitize Posteriors — Detection Probabilities + Integration Times

# %%
# Orbitize detection probabilities with integration times
testing = False

all_planets = list(orbit_params.keys())
start_date, end_date = "2026-12-01", "2028-06-30"
orbit_props_dir = '/Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_orbitize/'

summary_dict_orb = init_summary_dict()

for p, planet in enumerate(all_planets):
    bands, obs_modes, contrast_curves, show_wfov = get_planet_config(planet)
    summary_dict_orb['planet'].append(planet)

    print(f'\n{"="*60}')
    print(f'Planet {p+1}/{len(all_planets)}: {planet}')
    print(f'  Bands: {bands}, WFOV: {show_wfov}')
    print(f'{"="*60}')

    for band in bands:
        fname_in = f"{planet}_{start_date}_to_{end_date}_Orbitize"
        fname_out = fname_in + f'_Band{band}'

        # Load point cloud
        point_cloud_fname = f"{fname_in}_PointCloud.pkl"
        point_cloud = load_point_cloud(planet, i_dir=orbit_props_dir,
                                       fname=point_cloud_fname)

        csv_data = process_planet_band(
            planet, band, point_cloud,
            obs_mode=obs_modes[band],
            concurve=contrast_curves[band],
            summary_dict=summary_dict_orb,
            orbit_props_dir=orbit_props_dir,
            fname_out=fname_out,
            show_wfov=show_wfov,
            start_date=start_date, end_date=end_date,
        )

        if testing:
            break

    # Fill None for bands this planet doesn't use
    fill_missing_bands(summary_dict_orb, bands)

    if testing:
        break

# Save summary
print('\nSaving Orbitize summary table...')
summary_df_orb = pd.DataFrame(summary_dict_orb)
summary_fpath = os.path.join(orbit_props_dir,
                             f'detection_summary_{start_date}_to_{end_date}.csv')
summary_df_orb.to_csv(summary_fpath, index=False)
print(f'Summary saved to {summary_fpath}')
# Out:
# ...
# Planet 1/3: eps_Eri_b
#   Bands: [1, 4], WFOV: True
# ...
# Loading point cloud from /Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_orbitize/eps_Eri_b_2026-12-01_to_2028-06-30_Orbitize_PointCloud.pkl
#   Calculating flux contrast & detectability (band 1)...
#   Calculating integration times (band 1)...
# Imported HIPfromSimbad (implementation) from EXOSIMS.StarCatalog.HIPfromSimbad
# Imported corgietc (named file) from /opt/homebrew/a[...]ages/corgietc/corgietc.py
# Imported Stark (implementation) from EXOSIMS.ZodiacalLight.Stark
# Imported PostProcessing (prototype) from EXOSIMS.Prototypes.PostProcessing
# Imported GalaxiesFaintStars (implementation) from EXOSIMS.BackgroundSources.GalaxiesFaintStars
# Imported Completeness (prototype) from EXOSIMS.Prototypes.Completeness
# Imported PlanetPopulation (prototype) from EXOSIMS.Prototypes.PlanetPopulation
# Imported ForecasterMod (implementation) from EXOSIMS.PlanetPhysicalModel.ForecasterMod
# ...

# %% [markdown]
# ### Display Summary Tables

# %%
# Display RadVel detection probabilities
def extract_single_targ_pdet_summary(alltargs_df, planet_index, band):
    columns = ['mean_pdet', 'peak_pdet_window', 'separation_range',
               'flux_contrast_range', 'mag_range',
               'inttime_opt_range', 'inttime_con_range']
    singletarg_dict = {}
    for s in range(1, len(semesters) + 1):
        mean_pdet = alltargs_df.loc[planet_index, f'mean_pdet_sem{s}_band{band}']
        if mean_pdet is not None:
            mean_pdet = str(mean_pdet).lstrip('-')
        peak_pdet = alltargs_df.loc[planet_index, f'peak_pdet_sem{s}_band{band}']
        peak_date = alltargs_df.loc[planet_index, f'peak_date_sem{s}_band{band}']
        if peak_pdet is not None:
            peak_pdetanddate = f"{peak_pdet}, {peak_date}".lstrip('-')
        else:
            peak_pdetanddate = None
        singletarg_dict[s] = [
            mean_pdet, peak_pdetanddate,
            alltargs_df.loc[planet_index, f'sep_range_sem{s}_band{band}'],
            alltargs_df.loc[planet_index, f'fc_range_sem{s}_band{band}'],
            alltargs_df.loc[planet_index, f'mag_range_sem{s}_band{band}'],
            alltargs_df.loc[planet_index, f'inttime_opt_range_sem{s}_band{band}'],
            alltargs_df.loc[planet_index, f'inttime_con_range_sem{s}_band{band}'],
        ]
    return pd.DataFrame.from_dict(singletarg_dict, orient='index', columns=columns)

# RadVel summary
alltargs_rv = pd.DataFrame(summary_dict_rv)
alltargs_rv.sort_values('peak_pdet_sem1_band1', ascending=False, inplace=True)
print("=== RadVel Summary ===")
display(Table.from_pandas(alltargs_rv)[
    'planet', 'peak_pdet_sem1_band1', 'peak_pdet_sem2_band1', 'peak_pdet_sem3_band1'])

temp = alltargs_rv.set_index('planet')
for planet_name in temp.index:
    print(f'\n--- {planet_name} ---')
    planet_key = '_'.join(planet_name.split(' ')) if ' ' in planet_name else planet_name
    planet_bands = get_planet_config(planet_key)[0] if planet_key in orbit_params else [1, 3, 4]
    for band in planet_bands:
        print(f'  Band {band}')
        df = extract_single_targ_pdet_summary(temp, planet_name, band)
        display(Table.from_pandas(df))

# %%
# Orbitize summary
alltargs_orb = pd.DataFrame(summary_dict_orb)
alltargs_orb.sort_values('peak_pdet_sem1_band1', ascending=False, inplace=True)
print("=== Orbitize Summary ===")
display(Table.from_pandas(alltargs_orb)[
    'planet', 'peak_pdet_sem1_band1', 'peak_pdet_sem2_band1', 'peak_pdet_sem3_band1'])

temp = alltargs_orb.set_index('planet')
for planet_name in temp.index:
    print(f'\n--- {planet_name} ---')
    planet_key = '_'.join(planet_name.split(' ')) if ' ' in planet_name else planet_name
    planet_bands = get_planet_config(planet_key)[0] if planet_key in orbit_params else [1, 3, 4]
    for band in planet_bands:
        print(f'  Band {band}')
        df = extract_single_targ_pdet_summary(temp, planet_name, band)
        display(Table.from_pandas(df))
