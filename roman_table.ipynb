# %% [markdown]
# # Generates orbit propagation

# %% [markdown]
# ### Imports

# %%
# Autoreload extension
# %load_ext autoreload
# %autoreload 2

# %%
# Standard imports
import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

from roman_table import *

# %% [markdown]
# ### Main

# %%
# Directory setup
posterior_dir = '/Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits'
output_dir = '/Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props'

# %%
planets = list(display_names.keys())
start_date, end_date = "2027-01-01", "2028-06-30"
time_interval = 5 # days
inc_mode = 'random'
nsamp= 100000
plot=True
override_lan=0.
inc_params=None

# Loop over target planets
for p,planet in enumerate(planets):
    print(f'Planet index {p}/{len(planets)-1}: {planet}')

    output = f'{planet}_{start_date}_to_{end_date}_RVOnly'

    df = load_posteriors(planet,
                    posterior_dir,
                    format="radvel"
                    )

    # # Generate and save orbit point cloud
    point_cloud = gen_point_cloud(planet, df,
                  output_dir=output_dir,
                  start_date=start_date,
                  end_date=end_date,
                  time_interval=time_interval,
                  inc_mode=inc_mode,
                  override_lan=override_lan,
                  nsamp=nsamp,
                  out_fname=output,
                  standard_arr_size=False)

    # # Load a previously generated point cloud
    # point_cloud_fname = f"{output}_PointCloud.pkl"
    # point_cloud = load_point_cloud(planet,
    #                  i_dir=output_dir,
    #                  fname=point_cloud_fname
    #                  )

    # Generate and save summary csv and plots
    csv_data = gen_summary_csv(
        planet,
        point_cloud,
        output_dir,
        output)
    
    plot_orbital_parameters(csv_data,
                            planet,
                            start_date=start_date,
                            end_date=end_date,
                            output_prefix=os.path.join(output_dir,output),
                            fig_ext='pdf',
                            show_plots=True)
