# %% [markdown]
# # Generates orbit propagation

# %% [markdown]
# ### Imports

# %%
import os, numpy as np, pandas as pd
from astropy.time import Time
from radvel.basis import Basis
from radvel.utils import Msini
from orbitize.basis import tp_to_tau
from orbitize.kepler import calc_orbit
from astropy import units as u
from pathlib import Path
import argparse
import matplotlib.pyplot as plt

from roman_table import *

# %% [markdown]
# ### Target info

# %%
# Display names for prettier output
display_names={
    "47_UMa":"47 UMa c",
    "55_Cnc":"55 Cancri d",
    "eps_Eri":"Eps Eri b",
    "HD_87883":"HD 87883 b",
    "HD_114783":"HD 114783 c",
    "HD_134987":"HD 134987 c",
    "HD_154345":"HD 154345 b",
    "HD_160691":"HD 160691 e",
    "HD_190360":"HD 190360 b",
    "HD_217107":"HD 217107 c",
    "pi_Men":"Pi Men b",
    "ups_And":"Ups And d",
    "HD_192310":"HD 192310 c",
}

orbit_params={
    "47_UMa":{
        "basis":"per tc secosw sesinw k",
        "m0":1.0051917028549999,"m0_err":0.0468882076437500,
        "plx":72.452800,"plx_err":0.150701,
        "n_planets":3,"pl_num":2,"g_mag":4.866588,
    },
    "55_Cnc":{
        "basis":"per tc secosw sesinw k",
        "m0":0.905,"m0_err":0.015,
        "plx":79.4274000,"plx_err":0.0776646,
        "n_planets":5,"pl_num":3,"g_mag":5.732681,
    },
    "eps_Eri":{
        "basis":"per tc secosw sesinw k",
        "m0":0.82,"m0_err":0.02,
        "plx":312.219000,"plx_err":0.467348,
        "n_planets":1,"pl_num":1,"g_mag":3.465752,"inc_mean":78.810,"inc_sig":29.340
    },
    "HD_87883":{
        "basis":"per tc secosw sesinw k",
        "m0":0.810,"m0_err":0.091,
        "plx":54.6421000,"plx_err":0.0369056,
        "n_planets":1,"pl_num":1,"g_mag":7.286231,"inc_mean":25.45,"inc_sig":1.61
    },
    "HD_114783":{
        "basis":"per tc secosw sesinw k",
        "m0":0.90,"m0_err":0.04,
        "plx":47.4482000,"plx_err":0.0637202,
        "n_planets":2,"pl_num":2,"g_mag":7.330857,"inc_mean":159,"inc_sig":6
    },
    "HD_134987":{
        "basis":"per tc secosw sesinw k",
        "m0":1.0926444945650000,"m0_err":0.0474835459017250,
        "plx":38.1678000,"plx_err":0.0746519,
        "n_planets":2,"pl_num":2,"g_mag":6.302472,
    },
    "HD_154345":{
        "basis":"per tc secosw sesinw k",
        "m0":0.88,"m0_err":0.09,
        "plx":54.6636000,"plx_err":0.0212277,
        "n_planets":1,"pl_num":1,"g_mag":6.583667,"inc_mean":69,"inc_sig":13
    },
    "HD_160691":{
        "basis":"per tc secosw sesinw k",
        "m0":1.13,"m0_err":0.02,
        "plx":64.082,"plx_err":0.120162,
        "n_planets":4,"pl_num":4,"g_mag":4.942752,
    },
    "HD_190360":{
        "basis":"per tc secosw sesinw k",
        "m0":1.0,"m0_err":0.1,
        "plx":62.4443000,"plx_err":0.0616881,
        "n_planets":2,"pl_num":1,"g_mag":5.552787,"inc_mean":80.2,"inc_sig":23.2
    },
    "HD_217107":{
        "basis":"per tc secosw sesinw k",
        "m0":1.05963082882500,"m0_err":0.04470613802572,
        "plx":49.8170000,"plx_err":0.0573616,
        "n_planets":2,"pl_num":2,"g_mag":5.996743, "inc_mean":89.3,"inc_sig":9.0
    },
    "pi_Men":{
        "basis":"per tc secosw sesinw k",
        "m0":1.10,"m0_err":0.14,
        "plx":54.705200,"plx_err":0.067131,
        "n_planets":1,"pl_num":1,"g_mag":5.511580,"inc_mean":54.436,"inc_sig":5.945
    },
    "ups_And":{
        "basis":"per tc secosw sesinw k",
        "m0":1.29419667430000,"m0_err":0.04122482369025,
        "plx":74.571100,"plx_err":0.349118,
        "n_planets":3,"pl_num":3,"g_mag":3.966133, "inc_mean":23.758,"inc_sig":1.316
    },
    "HD_192310":{
        "basis":"per tc secosw sesinw k",
        "m0":0.84432448757250,"m0_err":0.02820926681885,
        "plx":113.648000,"plx_err":0.118606,
        "n_planets":2,"pl_num":2,"g_mag":5.481350
    },
}

# %% [markdown]
# ### Main

# %%
planets = display_names.keys()
semester_dict = {
    1 : ["2027-01-01","2027-06-01"],
    2 : ["2027-06-01","2028-01-01"],
    3 : ["2028-01-01","2028-06-01"],
}
time_interval = 5 # days
use_inc_priors = False
nsamp='all'
plot=True
posterior_dir = '/Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits'
output_dir = '/Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props'

for semester in semester_dict.keys():
    start_date, end_date = semester_dict[semester]

    for planet in planets:

        output = f'{planet}_Semester{semester}_RVOnly.csv'

        params=orbit_params[planet]

        if use_inc_priors:
            raise Error('Use of inclination priors not configured.')
            # has_gaussian_info="inc_mean" in params and "inc_sig" in params

            # if has_gaussian_info:
            #     inclination="gaussian"
            # else:
            #     inclination = "random"

        else: 
            inc_mode='random'
            inclination = "random"

        base_path=Path(posterior_dir)
        planet_dir=base_path/planet
        files=list(planet_dir.glob("*.csv.bz2"))
        if not files:
            print(f"Error: No posterior data found for {planet} in {planet_dir}")
            continue

        print(f"Loading posterior data from {files[0]}...")
        df=pd.read_csv(files[0])
        if nsamp=='all':
            nsamp=len(df)
            print(f"Using all {nsamp} posterior samples")

        print()
        print("-"*60)
        print(f"Configuration:")
        print(f"  Planet: {display_names[planet]}")
        print(f"  Date range: {start_date} to {end_date}")
        print(f"  Time interval: {time_interval} days")

        if inc_mode=='user_gaussian':
            print(f"  Inclination: Gaussian (μ={inc_value:.1f}°, σ={inc_uncertainty:.1f}°) [user-defined]")
            inc_display=f"{inc_value:.1f}±{inc_uncertainty:.1f}"
        elif inc_mode=='gaussian' and has_gaussian_info:
            print(f"  Inclination: Gaussian (μ={params['inc_mean']:.1f}°, σ={params['inc_sig']:.1f}°)")
            inc_display=f"gaussian (μ={params['inc_mean']:.1f}°, σ={params['inc_sig']:.1f}°)"
        elif inc_mode=='fixed':
            print(f"  Inclination: {inc_value:.1f}° (fixed)")
            inc_display=f"{inc_value:.1f}"
        else:
            print(f"  Inclination: random (uniform)")
            inc_display="random"

        print(f"  Posterior samples: {nsamp}")
        print(f"  Generate plots: {'Yes' if plot else 'No'}")
        print("-"*60)
        print()

        override_lan=0.

        t_start=Time(start_date)
        t_end=Time(end_date)

        if t_end<=t_start:
            raise Error("Error: End date must be after start date")

        print(f"Sampling {nsamp} orbits from posterior...")
        df_sample=df.sample(nsamp,replace=True)

        n_epochs=int((t_end.mjd-t_start.mjd)/time_interval)+1
        epochs=Time(np.linspace(t_start.mjd,t_end.mjd,n_epochs),format="mjd")

        print(f"Computing separations for {n_epochs} epochs...")


        seps,raoff,deoff,m_pl,inc,true_anomaly,z_mas=compute_sep(
            df_sample,epochs,
            params["basis"],params["m0"],params["m0_err"],
            params["plx"],params["plx_err"],
            params["n_planets"],params["pl_num"],
            override_lan=override_lan,
            # override_inc=override_inc,
            # inc_mean=params.get("inc_mean"),
            # inc_sig=params.get("inc_sig"),
            # user_inc_mean=user_inc_mean,
            # user_inc_sig=user_inc_sig
        )

        r_3d=np.sqrt(raoff**2+deoff**2+z_mas**2)
        phase_angle_rad=np.arccos(z_mas/r_3d)
        phase_angle_deg=np.degrees(phase_angle_rad)

        m_pl_mjup=m_pl*(u.M_sun/u.M_jup).to('')
        m_pl_mearth=m_pl*(u.M_sun/u.M_earth).to('')

        mass_intervals=np.array([0,2.04,95.16,317.828407,26635.6863,np.inf])
        C=np.array([0.00346053,-0.06613329,0.48091861,1.04956612,-2.84926757])
        S=np.array([0.279,0.50376436,0.22725968,0,0.881])
        r_pl_rearth=np.zeros_like(m_pl_mearth)
        for i in range(len(mass_intervals)-1):
            mask=(m_pl_mearth>=mass_intervals[i])&(m_pl_mearth<mass_intervals[i+1])
            if np.any(mask):
                r_pl_rearth[mask]=10**(C[i]+S[i]*np.log10(m_pl_mearth[mask]))

        r_pl_rjup=r_pl_rearth*(u.R_earth/u.R_jup).to('')

        inc_deg=np.degrees(inc)
        mass_median=np.median(m_pl_mjup)
        mass_16th=np.percentile(m_pl_mjup,16)
        mass_84th=np.percentile(m_pl_mjup,84)
        mass_err_lower=mass_median-mass_16th
        mass_err_upper=mass_84th-mass_median
        rad_median=np.median(r_pl_rjup)
        rad_16th=np.percentile(r_pl_rjup,16)
        rad_84th=np.percentile(r_pl_rjup,84)
        rad_err_lower=rad_median-rad_16th
        rad_err_upper=rad_84th-rad_median
        inc_median=np.median(inc_deg)
        inc_16th=np.percentile(inc_deg,16)
        inc_84th=np.percentile(inc_deg,84)

        print(f"Planet mass: {mass_median:.2f} +{mass_err_upper:.2f}/-{mass_err_lower:.2f} M_Jup")
        print(f"Planet radius: {rad_median:.2f} +{rad_err_upper:.2f}/-{rad_err_lower:.2f} R_Jup")
        print(f"Inclination: {inc_median:.2f} [{inc_16th:.2f}, {inc_84th:.2f}] degrees")
        print()

        # This is where we weight the posteriors by lnlike

        # Get lnlike for weighting the posteriors
        myBasis=Basis(params["basis"],params["n_planets"])
        df_synth=myBasis.to_synth(df_sample)
        lnlike=df_synth["lnprobability"].values

        weights=np.exp(lnlike-np.max(lnlike))
        weights=weights/np.sum(weights)

        med_sep=weighted_percentile(seps,weights,50)
        low_sep=weighted_percentile(seps,weights,16)
        high_sep=weighted_percentile(seps,weights,84)
        low_sep_95=weighted_percentile(seps,weights,2.5)
        high_sep_95=weighted_percentile(seps,weights,97.5)

        distance_pc=1000.0/params["plx"]
        med_rad_au=med_sep*distance_pc/1000.0
        low_rad_au=low_sep*distance_pc/1000.0
        high_rad_au=high_sep*distance_pc/1000.0
        low_rad_au_95=low_sep_95*distance_pc/1000.0
        high_rad_au_95=high_sep_95*distance_pc/1000.0
        med_phase=weighted_percentile(phase_angle_deg,weights,50)
        low_phase=weighted_percentile(phase_angle_deg,weights,16)
        high_phase=weighted_percentile(phase_angle_deg,weights,84)
        low_phase_95=weighted_percentile(phase_angle_deg,weights,2.5)
        high_phase_95=weighted_percentile(phase_angle_deg,weights,97.5)

        true_anomaly_deg=np.degrees(true_anomaly)
        true_anomaly_deg=true_anomaly_deg%360
        med_nu=weighted_percentile(true_anomaly_deg,weights,50)
        low_nu=weighted_percentile(true_anomaly_deg,weights,16)
        high_nu=weighted_percentile(true_anomaly_deg,weights,84)

        csv_data=pd.DataFrame({
            'date_iso':epochs.iso,
            'mjd':epochs.mjd,
            'decimal_year':epochs.decimalyear,
            'separation_mas_median':med_sep,
            'separation_mas_16th':low_sep,
            'separation_mas_84th':high_sep,
            'separation_mas_2.5th':low_sep_95,
            'separation_mas_97.5th':high_sep_95,
            'separation_au_median':med_rad_au,
            'separation_au_16th':low_rad_au,
            'separation_au_84th':high_rad_au,
            'separation_au_2.5th':low_rad_au_95,
            'separation_au_97.5th':high_rad_au_95,
            'phase_angle_deg_median':med_phase,
            'phase_angle_deg_16th':low_phase,
            'phase_angle_deg_84th':high_phase,
            'phase_angle_deg_2.5th':low_phase_95,
            'phase_angle_deg_97.5th':high_phase_95,
            'true_anomaly_deg_median':med_nu,
            'true_anomaly_deg_16th':low_nu,
            'true_anomaly_deg_84th':high_nu,
        })

        # output file name
        if output is None:
            planet_name=planet.replace("_","")
            output_file=f"{planet_name}_separations_{start_date}_to_{end_date}.csv"
        else:
            output_file=output

        output_fpath = os.path.join(output_dir,output_file)
        print(f"Writing output to {output_fpath}...")
        with open(output_fpath,'w') as f:
            f.write(f"# Planet: {display_names[planet]}\n")
            f.write(f"# Date range: {start_date} to {end_date}\n")
            f.write(f"# Time interval: {time_interval} days\n")
            f.write(f"# Inclination: {inc_display}\n")
            f.write(f"# Number of posterior samples: {nsamp}\n")
            f.write(f"# Number of epochs: {n_epochs}\n")
            f.write(f"#\n")
            f.write(f"# System parameters:\n")
            f.write(f"# Distance: {distance_pc:.2f} pc (parallax: {params['plx']:.2f} +/- {params['plx_err']:.2f} mas)\n")
            f.write(f"#\n")
            f.write(f"# Derived parameters:\n")
            f.write(f"# Planet mass: {mass_median:.3f} +{mass_err_upper:.3f}/-{mass_err_lower:.3f} M_Jup\n")
            f.write(
                f"# Planet radius: {rad_median:.3f} +{rad_err_upper:.3f}/-{rad_err_lower:.3f} R_Jup\n")
            f.write(
                f"# Inclination distribution: {inc_median:.2f} deg (median), [{inc_16th:.2f}, {inc_84th:.2f}] deg (16th-84th percentile)\n")
            f.write("#\n")
            csv_data.to_csv(f,index=False)

        print(f"Output saved to {output_fpath}")
        print(f"\nSummary:")
        print(f"  Planet: {display_names[planet]}")
        print(f"  Distance: {distance_pc:.2f} pc")
        print(f"  Epochs: {n_epochs}")
        print(
            f"  Separation range: {med_sep.min():.2f} - {med_sep.max():.2f} mas ({med_rad_au.min():.2f} - {med_rad_au.max():.2f} AU)")

        # Generate plots if requested
        if plot:
            print("\nGenerating plots...")
            output_prefix=output_fpath.replace('.csv','')
            plot_orbital_parameters(
                csv_data,
                display_names[planet],
                output_prefix,
                df_sample=df_sample,
                params=params,
                # override_inc=override_inc,
                override_lan=override_lan,
                # user_inc_mean=user_inc_mean,
                # user_inc_sig=user_inc_sig,
                start_date=start_date,
                end_date=end_date
            )
# Out:
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/47_UMa/47UMa_radvel_chains.csv.bz2...
# Using all 165456 posterior samples
#
# ------------------------------------------------------------
# Configuration:
#   Planet: 47 UMa c
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.56 +0.33/-0.08 M_Jup
# Planet radius: 0.88 +0.10/-0.03 R_Jup
# Inclination: 90.06 [47.07, 133.08] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester1_RVOnly.csv
#
# Summary:
#   Planet: 47 UMa c
#   Distance: 13.80 pc
#   Epochs: 31
#   Separation range: 161.82 - 175.15 mas (2.23 - 2.42 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/55_Cnc/55Cnc_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: 55 Cancri d
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 3.93 +2.35/-0.47 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.96 [47.02, 132.83] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester1_RVOnly.csv
#
# Summary:
#   Planet: 55 Cancri d
#   Distance: 12.59 pc
#   Epochs: 31
#   Separation range: 259.69 - 279.84 mas (3.27 - 3.52 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/eps_Eri/22049_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Eps Eri b
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.74 +0.44/-0.10 M_Jup
# Planet radius: 0.93 +0.07/-0.03 R_Jup
# Inclination: 90.14 [47.09, 132.75] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester1_RVOnly.csv
#
# Summary:
#   Planet: Eps Eri b
#   Distance: 3.20 pc
#   Epochs: 31
#   Separation range: 611.07 - 721.18 mas (1.96 - 2.31 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_87883/HD87883_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 87883 b
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 2.64 +1.53/-0.38 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.99 [47.39, 132.93] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 87883 b
#   Distance: 18.30 pc
#   Epochs: 31
#   Separation range: 181.25 - 194.16 mas (3.32 - 3.55 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_114783/HD114783_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 114783 c
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.82 +0.49/-0.11 M_Jup
# Planet radius: 0.96 +0.04/-0.03 R_Jup
# Inclination: 90.00 [46.97, 132.96] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 114783 c
#   Distance: 21.08 pc
#   Epochs: 31
#   Separation range: 126.19 - 143.26 mas (2.66 - 3.02 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_134987/HD134987_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 134987 c
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 1.23 +0.73/-0.15 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.92 [47.27, 133.02] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 134987 c
#   Distance: 26.20 pc
#   Epochs: 31
#   Separation range: 152.79 - 163.04 mas (4.00 - 4.27 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_154345/HD154345_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 154345 b
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 1.26 +0.74/-0.18 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.02 [47.10, 132.56] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 154345 b
#   Distance: 18.29 pc
#   Epochs: 31
#   Separation range: 187.76 - 207.23 mas (3.43 - 3.79 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_160691/HD160691_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 160691 e
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 2.14 +1.28/-0.26 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.12 [47.13, 132.99] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 160691 e
#   Distance: 15.61 pc
#   Epochs: 31
#   Separation range: 143.32 - 173.27 mas (2.24 - 2.70 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_190360/HD190360_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 190360 b
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 1.75 +1.02/-0.24 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.85 [46.98, 132.72] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 190360 b
#   Distance: 16.01 pc
#   Epochs: 31
#   Separation range: 137.31 - 180.80 mas (2.20 - 2.90 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_217107/HD217107_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 217107 c
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 4.97 +2.92/-0.60 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.07 [47.08, 132.81] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 217107 c
#   Distance: 20.07 pc
#   Epochs: 31
#   Separation range: 103.48 - 115.94 mas (2.08 - 2.33 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/pi_Men/39091_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Pi Men b
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 11.64 +6.74/-1.74 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.00 [47.14, 132.99] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester1_RVOnly.csv
#
# Summary:
#   Planet: Pi Men b
#   Distance: 18.28 pc
#   Epochs: 31
#   Separation range: 257.29 - 274.20 mas (4.70 - 5.01 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/ups_And/9826_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Ups And d
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 4.61 +2.73/-0.56 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.10 [46.93, 132.66] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester1_RVOnly.csv
#
# Summary:
#   Planet: Ups And d
#   Distance: 13.41 pc
#   Epochs: 31
#   Separation range: 92.93 - 161.99 mas (1.25 - 2.17 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_192310/192310_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 192310 c
#   Date range: 2027-01-01 to 2027-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.08 +0.04/-0.01 M_Jup
# Planet radius: 0.38 +0.10/-0.03 R_Jup
# Inclination: 90.09 [47.22, 132.86] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester1_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester1_RVOnly.csv
#
# Summary:
#   Planet: HD 192310 c
#   Distance: 8.80 pc
#   Epochs: 31
#   Separation range: 101.06 - 134.81 mas (0.89 - 1.19 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester1_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/47_UMa/47UMa_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: 47 UMa c
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 0.56 +0.33/-0.08 M_Jup
# Planet radius: 0.88 +0.10/-0.03 R_Jup
# Inclination: 90.39 [47.34, 133.10] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester2_RVOnly.csv
#
# Summary:
#   Planet: 47 UMa c
#   Distance: 13.80 pc
#   Epochs: 43
#   Separation range: 170.76 - 213.84 mas (2.36 - 2.95 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/55_Cnc/55Cnc_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: 55 Cancri d
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 3.93 +2.34/-0.48 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.96 [47.16, 132.80] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester2_RVOnly.csv
#
# Summary:
#   Planet: 55 Cancri d
#   Distance: 12.59 pc
#   Epochs: 43
#   Separation range: 239.70 - 294.18 mas (3.02 - 3.70 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/eps_Eri/22049_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Eps Eri b
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 0.74 +0.43/-0.10 M_Jup
# Planet radius: 0.93 +0.07/-0.03 R_Jup
# Inclination: 89.94 [47.43, 132.65] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester2_RVOnly.csv
#
# Summary:
#   Planet: Eps Eri b
#   Distance: 3.20 pc
#   Epochs: 43
#   Separation range: 712.59 - 963.61 mas (2.28 - 3.09 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_87883/HD87883_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 87883 b
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 2.64 +1.53/-0.38 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.11 [47.34, 132.89] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 87883 b
#   Distance: 18.30 pc
#   Epochs: 43
#   Separation range: 192.72 - 210.88 mas (3.53 - 3.86 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_114783/HD114783_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 114783 c
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 0.82 +0.49/-0.11 M_Jup
# Planet radius: 0.96 +0.04/-0.03 R_Jup
# Inclination: 89.65 [46.73, 132.59] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 114783 c
#   Distance: 21.08 pc
#   Epochs: 43
#   Separation range: 145.24 - 182.31 mas (3.06 - 3.84 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_134987/HD134987_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 134987 c
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 1.23 +0.73/-0.15 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.25 [47.34, 132.68] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 134987 c
#   Distance: 26.20 pc
#   Epochs: 43
#   Separation range: 161.03 - 182.88 mas (4.22 - 4.79 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_154345/HD154345_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 154345 b
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 1.26 +0.74/-0.18 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.08 [47.14, 132.83] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 154345 b
#   Distance: 18.29 pc
#   Epochs: 43
#   Separation range: 207.02 - 213.48 mas (3.79 - 3.91 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_160691/HD160691_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 160691 e
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 2.14 +1.26/-0.26 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.23 [47.24, 132.76] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 160691 e
#   Distance: 15.61 pc
#   Epochs: 43
#   Separation range: 189.05 - 243.13 mas (2.95 - 3.79 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_190360/HD190360_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 190360 b
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 1.75 +1.03/-0.24 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.98 [47.12, 132.63] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 190360 b
#   Distance: 16.01 pc
#   Epochs: 43
#   Separation range: 113.43 - 134.32 mas (1.82 - 2.15 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_217107/HD217107_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 217107 c
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 4.97 +2.98/-0.60 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.11 [47.35, 133.05] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 217107 c
#   Distance: 20.07 pc
#   Epochs: 43
#   Separation range: 119.31 - 173.37 mas (2.40 - 3.48 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/pi_Men/39091_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Pi Men b
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 11.65 +6.73/-1.74 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.08 [47.13, 132.98] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester2_RVOnly.csv
#
# Summary:
#   Planet: Pi Men b
#   Distance: 18.28 pc
#   Epochs: 43
#   Separation range: 274.26 - 279.26 mas (5.01 - 5.10 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/ups_And/9826_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Ups And d
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 4.60 +2.72/-0.56 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.86 [47.16, 132.81] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester2_RVOnly.csv
#
# Summary:
#   Planet: Ups And d
#   Distance: 13.41 pc
#   Epochs: 43
#   Separation range: 66.72 - 158.28 mas (0.89 - 2.12 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_192310/192310_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 192310 c
#   Date range: 2027-06-01 to 2028-01-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 43 epochs...
# Planet mass: 0.08 +0.04/-0.01 M_Jup
# Planet radius: 0.38 +0.10/-0.03 R_Jup
# Inclination: 89.91 [47.18, 132.96] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester2_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester2_RVOnly.csv
#
# Summary:
#   Planet: HD 192310 c
#   Distance: 8.80 pc
#   Epochs: 43
#   Separation range: 83.58 - 141.68 mas (0.74 - 1.25 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester2_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/47_UMa/47UMa_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: 47 UMa c
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.56 +0.33/-0.08 M_Jup
# Planet radius: 0.88 +0.10/-0.03 R_Jup
# Inclination: 90.06 [47.36, 132.86] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester3_RVOnly.csv
#
# Summary:
#   Planet: 47 UMa c
#   Distance: 13.80 pc
#   Epochs: 31
#   Separation range: 212.42 - 233.29 mas (2.93 - 3.22 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/47_UMa_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/55_Cnc/55Cnc_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: 55 Cancri d
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 3.92 +2.32/-0.47 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.17 [47.40, 133.01] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester3_RVOnly.csv
#
# Summary:
#   Planet: 55 Cancri d
#   Distance: 12.59 pc
#   Epochs: 31
#   Separation range: 326.95 - 359.87 mas (4.12 - 4.53 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/55_Cnc_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/eps_Eri/22049_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Eps Eri b
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.74 +0.44/-0.10 M_Jup
# Planet radius: 0.93 +0.07/-0.03 R_Jup
# Inclination: 90.10 [47.30, 132.95] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester3_RVOnly.csv
#
# Summary:
#   Planet: Eps Eri b
#   Distance: 3.20 pc
#   Epochs: 31
#   Separation range: 960.43 - 1094.08 mas (3.08 - 3.50 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/eps_Eri_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_87883/HD87883_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 87883 b
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 2.64 +1.53/-0.38 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.96 [47.16, 132.84] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 87883 b
#   Distance: 18.30 pc
#   Epochs: 31
#   Separation range: 211.30 - 223.04 mas (3.87 - 4.08 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_87883_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_114783/HD114783_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 114783 c
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.82 +0.49/-0.11 M_Jup
# Planet radius: 0.96 +0.04/-0.03 R_Jup
# Inclination: 89.94 [47.12, 132.92] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 114783 c
#   Distance: 21.08 pc
#   Epochs: 31
#   Separation range: 182.59 - 209.17 mas (3.85 - 4.41 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_114783_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_134987/HD134987_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 134987 c
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 1.23 +0.73/-0.15 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.16 [47.11, 133.01] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 134987 c
#   Distance: 26.20 pc
#   Epochs: 31
#   Separation range: 182.95 - 200.86 mas (4.79 - 5.26 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_134987_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_154345/HD154345_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 154345 b
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 1.26 +0.73/-0.18 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.10 [47.26, 132.96] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 154345 b
#   Distance: 18.29 pc
#   Epochs: 31
#   Separation range: 200.52 - 212.49 mas (3.67 - 3.89 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_154345_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_160691/HD160691_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 160691 e
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 2.14 +1.27/-0.26 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.98 [47.04, 132.77] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 160691 e
#   Distance: 15.61 pc
#   Epochs: 31
#   Separation range: 246.76 - 283.11 mas (3.85 - 4.42 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_160691_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_190360/HD190360_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 190360 b
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 1.75 +1.02/-0.24 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.05 [47.37, 132.96] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 190360 b
#   Distance: 16.01 pc
#   Epochs: 31
#   Separation range: 117.60 - 144.85 mas (1.88 - 2.32 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_190360_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_217107/HD217107_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 217107 c
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 4.97 +2.97/-0.61 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.14 [47.17, 132.91] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 217107 c
#   Distance: 20.07 pc
#   Epochs: 31
#   Separation range: 172.17 - 216.62 mas (3.46 - 4.35 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_217107_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/pi_Men/39091_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Pi Men b
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 11.63 +6.77/-1.74 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 90.00 [47.07, 132.81] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester3_RVOnly.csv
#
# Summary:
#   Planet: Pi Men b
#   Distance: 18.28 pc
#   Epochs: 31
#   Separation range: 264.04 - 277.44 mas (4.83 - 5.07 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/pi_Men_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/ups_And/9826_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Ups And d
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 4.60 +2.74/-0.56 M_Jup
# Planet radius: 1.00 +0.00/-0.00 R_Jup
# Inclination: 89.91 [47.24, 132.81] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester3_RVOnly.csv
#
# Summary:
#   Planet: Ups And d
#   Distance: 13.41 pc
#   Epochs: 31
#   Separation range: 158.10 - 201.01 mas (2.12 - 2.70 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/ups_And_Semester3_RVOnly_orbital_params.png
# Loading posterior data from /Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits/HD_192310/192310_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: HD 192310 c
#   Date range: 2028-01-01 to 2028-06-01
#   Time interval: 5 days
#   Inclination: random (uniform)
#   Posterior samples: 165456
#   Generate plots: Yes
# ------------------------------------------------------------
#
# Sampling 165456 orbits from posterior...
# Computing separations for 31 epochs...
# Planet mass: 0.08 +0.04/-0.01 M_Jup
# Planet radius: 0.38 +0.10/-0.03 R_Jup
# Inclination: 89.98 [47.08, 133.05] degrees
#
# Writing output to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester3_RVOnly.csv...
# Output saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester3_RVOnly.csv
#
# Summary:
#   Planet: HD 192310 c
#   Distance: 8.80 pc
#   Epochs: 31
#   Separation range: 79.94 - 139.36 mas (0.70 - 1.23 AU)
#
# Generating plots...
# Plot saved to /Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props/HD_192310_Semester3_RVOnly_orbital_params.png
