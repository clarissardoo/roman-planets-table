# %% [markdown]
# # Generate orbit propagation point clouds
#
# Runs orbit propagation for all CPP targets. RadVel and Orbitize posteriors are handled in separate cells.

# %% [markdown]
# ### Imports

# %%
# Autoreload extension
# %load_ext autoreload
# %autoreload 2

# %%
# Standard imports
import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

from roman_table import *

# %% [markdown]
# ### Shared Configuration

# %%
# Shared configuration
start_date, end_date = "2026-12-01", "2028-06-30"
time_interval = 10  # days
nsamp = 100000
plot = True

# Separate RadVel and Orbitize planets from orbit_params
radvel_planets = [p for p, v in orbit_params.items() if v.get('posterior_type', 'radvel') == 'radvel']
orbitize_planets = [p for p, v in orbit_params.items() if v.get('posterior_type', 'radvel') == 'orbitize']
all_planets = list(orbit_params.keys())

print(f"RadVel planets ({len(radvel_planets)}): {radvel_planets}")
print(f"Orbitize-only planets ({len(orbitize_planets)}): {orbitize_planets}")
# Out:
# RadVel planets (2): ['eps_Eri_b', 'ups_And_d']
# Orbitize-only planets (1): ['14_Her_b']

# %% [markdown]
# ### RadVel Posteriors (RV-Only)

# %%
# Directory setup
posterior_dir = '/Users/clarissardoo/Projects/roman_orbits/roman-table/orbit_fits/'
output_dir = '/Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_radvel/'
os.makedirs(output_dir, exist_ok=True)

inc_mode = None
override_lan = None

for p, planet in enumerate(radvel_planets):
    print(f'\n{"="*60}')
    print(f'Planet {p+1}/{len(radvel_planets)}: {planet}')
    print(f'{"="*60}')

    params = orbit_params[planet]
    output = f'{planet}_{start_date}_to_{end_date}_RVOnly'

    # Load RadVel posterior
    df = load_posteriors(planet, posterior_dir=posterior_dir, format="radvel")

    # Generate point cloud
    point_cloud = gen_point_cloud(
        planet, df,
        output_dir=output_dir,
        start_date=start_date, end_date=end_date,
        time_interval=time_interval,
        inc_mode=inc_mode,
        override_lan=override_lan,
        nsamp=nsamp,
        out_fname=output,
        standard_arr_size=False,
    )

    # Reload point cloud (ensures consistency with saved version)
    point_cloud_fname = f"{output}_PointCloud.pkl"
    point_cloud = load_point_cloud(planet, i_dir=output_dir, fname=point_cloud_fname)

    # Summary CSV and plots
    csv_data = gen_summary_csv(planet, point_cloud, output_dir, output)

    if plot:
        plot_orbital_parameters(
            planet, csv_data,
            params=params, df_sample=df,
            start_date=start_date, end_date=end_date,
            output_prefix=os.path.join(output_dir, output),
            fig_ext='png', show_plots=True,
            override_lan=override_lan,
        )
# Out:
# ...
# Planet 1/2: eps_Eri_b
# ...
# Loading RadVel posterior from /Users/clarissardoo/Projects/roman_orbits/roman-table/orbit_fits/eps_Eri/22049_radvel_chains.csv.bz2...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Eps Eri b
#   Date range: 2026-12-01 to 2028-06-30
#   Time interval: 10 days
#   Inclination: random (uniform with critical inclination constraint)
#   Posterior samples: 100000
# ------------------------------------------------------------
#
# Sampling 100000 orbits from posterior...
# Generating point cloud for 58 epochs...
# Using RadVel posterior format...
# Saving point cloud to /Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_radvel/eps_Eri_b_2026-12-01_to_2028-06-30_RVOnly_PointCloud.pkl
# Loading point cloud from /Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_radvel/eps_Eri_b_2026-12-01_to_2028-06-30_RVOnly_PointCloud.pkl
# Planet mass: 0.74 +0.43/-0.10 M_Jup
# ...

# %% [markdown]
# ### Orbitize Posteriors (RV+HGCA)

# %%
# Directory setup
posterior_dir = '/Users/clarissardoo/Projects/roman_orbits/roman-table/orbit_fits/'
output_dir = '/Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_orbitize/'
os.makedirs(output_dir, exist_ok=True)

for p, planet in enumerate(all_planets):
    print(f'\n{"="*60}')
    print(f'Planet {p+1}/{len(all_planets)}: {planet}')
    print(f'{"="*60}')

    params = orbit_params[planet]
    output = f'{planet}_{start_date}_to_{end_date}_Orbitize'

    # Load Orbitize posterior
    df = load_posteriors(planet, posterior_dir=posterior_dir, format="orbitize")

    # Generate point cloud
    point_cloud = gen_point_cloud(
        planet, df,
        output_dir=output_dir,
        start_date=start_date, end_date=end_date,
        time_interval=time_interval,
        nsamp=nsamp,
        out_fname=output,
        standard_arr_size=False,
        posterior_type='orbitize',
    )

    # Reload point cloud
    point_cloud_fname = f"{output}_PointCloud.pkl"
    point_cloud = load_point_cloud(planet, i_dir=output_dir, fname=point_cloud_fname)

    # Summary CSV and plots
    csv_data = gen_summary_csv(planet, point_cloud, output_dir, output)

    if plot:
        plot_orbital_parameters(
            planet, csv_data,
            params=params, df_sample=df,
            start_date=start_date, end_date=end_date,
            output_prefix=os.path.join(output_dir, output),
            fig_ext='png', show_plots=True,
            posterior_type='orbitize',
        )
# Out:
# ...
# Planet 1/3: eps_Eri_b
# ...
# Loading Orbitize posterior from /Users/clarissardoo/Projects/roman_orbits/roman-table/orbit_fits/Roman_RV_HGCA_Orbits/eps_Eri/eps_Eri_rv_hgca_posterior.csv...
#
# ------------------------------------------------------------
# Configuration:
#   Planet: Eps Eri b
#   Date range: 2026-12-01 to 2028-06-30
#   Time interval: 10 days
#   Inclination: from Orbitize posterior (sampled)
#   Ω (Omega): from Orbitize posterior (sampled)
#   Posterior samples: 100000
# ------------------------------------------------------------
#
# Sampling 100000 orbits from posterior...
# Generating point cloud for 58 epochs...
# Using Orbitize posterior format...
# Saving point cloud to /Users/clarissardoo/Projects/roman_orbits/roman-table/outputs/outputs_orbitize/eps_Eri_b_2026-12-01_to_2028-06-30_Orbitize_PointCloud.pkl
# ...
