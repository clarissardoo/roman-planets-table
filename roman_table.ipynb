# %% [markdown]
# # Generates orbit propagation

# %% [markdown]
# ### Imports

# %%
# Autoreload extension
# %load_ext autoreload
# %autoreload 2

# %%
# Standard imports
import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

from roman_table import *

# %% [markdown]
# ### Main

# %%
planets = list(display_names.keys())
start_date, end_date = "2027-01-01", "2028-06-30"
time_interval = 5 # days
use_inc_priors = False
nsamp= 100000
plot=True
posterior_dir = '/Users/sbogat/Documents/01_Research/exoplanner_workspace/data/orbit_fits'
output_dir = '/Users/sbogat/Documents/01_Research/exoplanner_workspace/output/orbit_props'
override_lan=0.
inc_params=None

# Loop over target planets
for p,planet in enumerate(planets):
    print(f'Planet index {p}/{len(planets)-1}: {planet}')

    output = f'{planet}_{start_date}_to_{end_date}_RVOnly.csv'

    # Temporary warning bc Ell broke the inclination priors
    if use_inc_priors:
        raise UserWarning('Use of inclination priors not configured.')
    else: 
        inc_mode='random'

    # Generate and save orbit point cloud
    point_cloud = gen_point_cloud(planet,
                  posterior_dir=posterior_dir,
                  output_dir=output_dir,
                  start_date=start_date,
                  end_date=end_date,
                  time_interval=time_interval,
                  inc_mode=inc_mode,
                  override_lan=override_lan,
                  nsamp=nsamp,
                  out_fname=output)

    # Load a previously generated point cloud
    point_cloud_fname = f"{planet}_{start_date}_to_{end_date}_RVOnly_PointCloud.pkl"
    point_cloud = load_point_cloud(planet,
                     i_dir=output_dir,
                     fname=point_cloud_fname
                     )
    
    # CURRENTLY BROKEN
    # Generate and save summary csv and plots
    # df_samples, csv_data = gen_orbit_csv(planet,params,
    #               posterior_dir,
    #               output_dir,
    #               start_date,
    #               end_date,
    #               time_interval,
    #               inc_mode,
    #               inc_params,
    #               override_lan,
    #               nsamp,
    #               output,
    #               plot,
    #               show_plots=True)

    break
